# %% [markdown]
# # Imports

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import os
import pandas as pd
import datetime
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

import sqlite3

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Calculate top items

# %% [markdown]
# ## Load data

# %%
CSV_PATH = "../data/csv/processed/"
files    = os.listdir(CSV_PATH)
csvs     = sorted([file.split('_')[1].split('.')[0] for file in files])

historic_csvs = csvs[:-1]
train_df      = pd.concat([pd.read_csv(f"{CSV_PATH}products_{csv}.csv") for csv in historic_csvs], ignore_index=True)

latest_csv = csvs[-1]
test_df    = pd.read_csv(f"{CSV_PATH}products_{latest_csv}.csv")

# %%
conn = sqlite3.connect("../data/sql/swipes.db")
labels = pd.read_sql_query("SELECT data_id, is_liked, is_superliked, is_passed FROM swipes", conn)
conn.close()

# %% [markdown]
# ## Pre-processing

# %%
stop_words = ['i','på','og','til']
vectorizer = CountVectorizer(binary=True, lowercase=True, stop_words=stop_words)
train_sentences = train_df['product_name'].tolist()
train_product_encoding = vectorizer.fit_transform(train_sentences).toarray()

test_sentences = test_df['product_name'].tolist()
test_product_encoding = vectorizer.transform(test_sentences).toarray()

# %%
onehot = ['brand','category']
preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown='ignore'), onehot),
    ("num", StandardScaler(), ['price'])
])
train_onehot = preprocessor.fit_transform(train_df).toarray()
test_onehot  = preprocessor.transform(test_df).toarray()
num_categories = sum(len(c) for c in preprocessor.named_transformers_['cat'].categories_)
print(f"Number of categories after one-hot encoding: {num_categories}")
# Out:
# Number of categories after one-hot encoding: 782

# %%
train_preprocessed = np.hstack((train_product_encoding, train_onehot))
test_preprocessed  = np.hstack((test_product_encoding, test_onehot))

train_df_preprocessed = pd.DataFrame(train_preprocessed, columns=[f"feature_{i}" for i in range(train_preprocessed.shape[1])])
train_df_preprocessed = pd.merge(train_df, train_df_preprocessed, left_index=True, right_index=True)

test_df_preprocessed = pd.DataFrame(test_preprocessed, columns=[f"feature_{i}" for i in range(test_preprocessed.shape[1])])
test_df_preprocessed = pd.merge(test_df, test_df_preprocessed, left_index=True, right_index=True)

# %%
train_df_features = train_df_preprocessed.iloc[:, len(train_df.columns):]
train_df_features['data_id'] = train_df_preprocessed['data_id']
train_df_features = pd.merge(train_df_features, labels, on='data_id', how='inner')

Xtrain = train_df_features.drop(columns=['data_id', 'is_liked', 'is_superliked', 'is_passed']).to_numpy()
ytrain = (train_df_features['is_liked'] | train_df_features['is_superliked']).to_numpy()

test_df_features  = test_df_preprocessed.iloc[:, len(test_df.columns):]
test_df_features['data_id'] = test_df_preprocessed['data_id']

Xtest = test_df_features.drop(columns=['data_id']).to_numpy()

# %% [markdown]
# ## Inference

# %%
# Duplicate samples based on weights
weights = np.where(train_df_features['is_superliked'] == 1, 10, 1)

# Repeat each row according to its weight
indices = np.repeat(np.arange(len(train_df_features)), weights)

Xtrain_weighted = Xtrain[indices]
ytrain_weighted = ytrain[indices]
train_df_features_weighted = train_df_features.iloc[indices].reset_index(drop=True)

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='cosine')
knn.fit(Xtrain_weighted, ytrain_weighted)
probas = knn.predict_proba(Xtest)

nb = GaussianNB()
nb.fit(Xtrain_weighted, ytrain_weighted)
probas = nb.predict_proba(Xtest)

xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(Xtrain_weighted, ytrain_weighted)
probas = xgb.predict_proba(Xtest)

# Probabilities for all test samples, and print in descending order of probability of being liked
sorted_indices = np.argsort(-probas[:, 1])  # Sort by probability of being liked (class 1)
for idx in sorted_indices:
    data_id = test_df_features.iloc[idx]['data_id']
    product_name = test_df[test_df['data_id'] == data_id]['product_name'].values[0]
    print(f"{probas[idx, 1]:.4f} {product_name}")
# Out:
# /home/mp/Desktop/grocery_swiper/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [16:24:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.9978 Agurk
# 0.9966 Hakket kylling 3-7%
# 0.9966 Hakket kylling 3-7%
# 0.9958 Lakseside
# 0.9919 Spidskål
# 0.9918 Gulerødder
# 0.9918 Gulerødder
# 0.9910 Kylling
# 0.9873 Laks i skiver
# 0.9870 Kikærter
# 0.9870 Hakkede Tomater
# 0.9870 Tomater
# 0.9870 Bønner
# 0.9866 Rodfrugter
# 0.9859 Lufttørret Skinke
# 0.9859 Salami Spicy Ventricina
# 0.9859 Skinke
# 0.9859 Chorizo
# 0.9859 Salami Milano Salame
# 0.9859 Jamon Serrano
# 0.9859 Salchichón
# 0.9859 Schwarzwaldskinke
# 0.9859 Mortadella
# 0.9841 Flæsk i skiver
# 0.9719 Tomater
# 0.9457 Hakkede Tomater med urter
# 0.9276 Hakket kalv og grisekød 8-12%
# 0.9209 Drikkeyoghurt Jordbær & Banan
# 0.9209 Drikkeyoghurt Jordbær
# 0.9178 Kyllingeunderlår
# 0.9028 Laks
# 0.9028 Laks i skiver
# 0.9005 Økologiske æg M/L
# 0.8990 Kyllingebryst
# 0.8989 Hakket grisekød 8-12%
# 0.8908 Kyllingebrystfilet
# 0.8908 Kyllingeoverlår
# 0.8867 Kylling & Baconsalat
# 0.8783 Hummus
# 0.8671 Tun i olie
# 0.8671 Tun i vand
# 0.8628 Toiletpapir
# 0.8174 Finthakket  Skinkesalat
# 0.8022 Køkkenrulle
# 0.7955 Fuet
# 0.7679 Appelsiner
# 0.7420 Drikkeyoghurt Multifrugt
# 0.7389 Æggesalat
# 0.7389 Æggesalat 30% mindre fedt
# 0.7389 Krabbesalat
# 0.7389 Hønsesalat
# 0.7227 Æblejuice
# 0.7196 Æblejuice
# 0.7175 Paté Hvidløg
# 0.7073 Hakket oksekød 4-7%
# 0.6667 Havrekiks med frugt
# 0.6660 Salami
# 0.6341 Grapefrugt
# 0.6323 Affaldsposer
# 0.5979 Rejer
# 0.5979 Rejer
# 0.5954 Morgenmild Juice
# 0.5954 Appelsinjuice
# 0.5928 Sønderjysk Spegepølse
# 0.5785 Vannameirejer
# 0.5664 Lasagneplader
# 0.5138 Rabeber & Æble Skyr
# 0.5138 Naturel Skyr
# 0.5138 Vanilje Skyr
# 0.5077 Multifrugtjuice
# 0.5077 Appelsinjuice
# 0.4793 Kødpølse - Den lette
# 0.4793 Oksespegepølse
# 0.4793 Jægerpølse - Den lette
# 0.4793 Kødpølse
# 0.4793 Kalkunspegepølse - Den lette
# 0.4793 Røget Medister
# 0.4793 Kartoffelspegepølse
# 0.4574 Double Sunlover Ispinde
# 0.4489 Jordbær Yoghurt
# 0.4155 Hamburgerryg
# 0.3963 Smoothie
# 0.3461 Jordbær Frugtdrik
# 0.2459 Indbagt Laks med Julienne sauce
# 0.2459 Indbagt Laks med Spinat og Ostesauce
# 0.1912 Hyldeblomst drik
# 0.1912 Sport Frugtdrik
# 0.1912 Hindbær Frugtdrik
# 0.1912 Solbær Frugtdrik
# 0.1896 Røget Medister
# 0.1774 Hvedepitabrød
# 0.1547 Fiskefrikadeller
# 0.1493 Vandmelon
# 0.1466 Træningstilskud
# 0.1466 Vaskemiddel-flydende
# 0.1447 Drikkeklar saft Jordbær
# 0.1446 Solskinsboller
# 0.1446 Cafe Sandwich Grov
# 0.1446 Solsikkerugbrød
# 0.1446 Rugbrødsskiver
# 0.1419 Kyllingebryst
# 0.1370 Fruit & Nut Granola
# 0.1370 Classic Granola
# 0.1370 Red Berries Granola
# 0.1370 Choco & Nuts Granola
# 0.1327 Pære & Banan Yoghurt
# 0.1327 Kirsebær Yoghurt
# 0.1198 Makrel Små Stykker
# 0.1178 Maskinopvask-tabs
# 0.1178 Mineraler
# 0.1178 Fiskeolie
# 0.1178 Kosttilskud
# 0.1178 Kosttilskud
# 0.1139 Hundesnacks
# 0.1139 Kattesnacks
# 0.1132 Hundeposer
# 0.1096 Revet ost Mexitopping
# 0.1096 Kakaomælk
# 0.1096 Iskaffe
# 0.1096 Vaniljedrik
# 0.1096 Corn Cakes Sour Cream & Onion
# 0.1096 Revet ost Pizzatopping
# 0.1096 Grød
# 0.1096 Corn Cakes Paprika
# 0.1096 Hytteost
# 0.1096 Mozzarella
# 0.1090 Kyllingepølser
# 0.1090 Vaskemiddel-tabs
# 0.1090 Frankfurter
# 0.1090 Vegansk Burgerbolle
# 0.1090 Grillpølser
# 0.1090 Hotdogpølser
# 0.1053 Ispinde
# 0.1053 Wonder Ispinde
# 0.1030 Slikposer
# 0.1030 Slikposer
# 0.1030 Slikposer
# 0.1030 Slikposer
# 0.1030 Slikposer
# 0.1027 Kartoffel Jordskoksuppe
# 0.1027 Tomatsuppe
# 0.0981 Træningstilskud
# 0.0927 Surdejsboller
# 0.0927 Hamburgerryg
# 0.0925 Kyllingelever
# 0.0920 Kyllingekebab
# 0.0889 Melboller
# 0.0889 Kød- og Melboller
# 0.0889 Tandpasta
# 0.0889 Tandbørste
# 0.0851 Tegnestifter
# 0.0844 Overstregningstusch
# 0.0844 Vaskemiddel-flydende
# 0.0844 Blyant
# 0.0844 Trusseindlæg
# 0.0844 Tamponer
# 0.0844 Bind
# 0.0827 Makrelfilet i Tomat
# 0.0826 Kyllingespyd
# 0.0805 Sportssodavand
# 0.0805 Sportssodavand
# 0.0803 Proteinbar
# 0.0782 Bacontern
# 0.0782 Baconskiver
# 0.0761 Corn Cakes Pizza
# 0.0755 Bagels Grov
# 0.0755 Bagels Plain
# 0.0755 Bagels chili og cheddar
# 0.0739 Finvalsede Havregryn
# 0.0707 Pasta
# 0.0706 Olivenolie
# 0.0703 Hvedemel
# 0.0703 Delikatess knækbrød
# 0.0703 Surdeg flerkorn knækbrød
# 0.0703 Drikkeklar saft Kiwi
# 0.0703 Drikkeklar saft Original
# 0.0703 Skyllemiddel
# 0.0703 Drikkeklar saft Citron
# 0.0703 Sport + knækbrød
# 0.0678 Cola
# 0.0670 Pizzasauce Basilikum
# 0.0663 Surdejsbaguette
# 0.0663 Hvedekerneboller
# 0.0663 Surdejsboller
# 0.0661 Hytteost
# 0.0661 Frugtstænger
# 0.0652 Sild
# 0.0652 Maskinopvask-tabs
# 0.0652 Solsikkekerne & Quinoa knækbrød
# 0.0652 Havreknækbrød
# 0.0652 Maskinopvask-gel
# 0.0652 Tempurarejer
# 0.0652 Choko Crunch
# 0.0652 Classic Crunch
# 0.0627 Balsam
# 0.0627 Shampoo
# 0.0627 Oksekødssuppe
# 0.0627 Deo Roll-on
# 0.0627 Pommes Frites Slim
# 0.0627 Curly Fries
# 0.0627 Hønsekødssuppe
# 0.0627 Tipo 00 Hvedemel
# 0.0627 Deo Roll-on
# 0.0627 Potato Grids
# 0.0627 Deospray
# 0.0627 Rugmel
# 0.0627 Manitobamel
# 0.0622 Pirogger Original
# 0.0622 Pirogger Chili Cheese
# 0.0619 Falafel
# 0.0619 Kyllingenuggets
# 0.0619 Gyros
# 0.0609 Kakaonibs
# 0.0609 Chiafrø
# 0.0609 Hampefrø
# 0.0601 Rengøringssvampe
# 0.0601 Mineralvand
# 0.0601 Nudler
# 0.0601 Tekstilpleje
# 0.0601 Finvalsede Havregryn
# 0.0598 Proteinbar
# 0.0579 Balsamico & Tomatochips
# 0.0579 Sea Salt Chips
# 0.0579 Paprikachips
# 0.0579 Sour Cream & Onion Chips
# 0.0572 Slikpose Eventyrland Sour
# 0.0572 Slikpose Eventyrland Rainbow Edition
# 0.0572 Bolsjer
# 0.0560 Chokoladebar
# 0.0560 Chokoladebar
# 0.0560 Chokoladebar
# 0.0548 Granola Honningristet
# 0.0548 Gojibær
# 0.0548 Øl - Alkoholfri
# 0.0548 Pizzadej
# 0.0548 Rengøring - universal
# 0.0548 Ketchup
# 0.0548 Skyllemiddel
# 0.0548 Vaskepulver
# 0.0548 Vaskemiddel-flydende
# 0.0548 Tom Yum Suppe
# 0.0548 Ravioli Chicken Lemon
# 0.0548 Smør
# 0.0548 Smørbar
# 0.0548 Hårmousse
# 0.0548 Flydende sæbe
# 0.0548 Kiks
# 0.0548 Hårspray
# 0.0548 Tebreve
# 0.0548 Hårspray
# 0.0548 Instant Te Choco Orange
# 0.0548 Instant Te Karamel
# 0.0548 Instant Te Vanilje
# 0.0548 Instant Te Grøn Te
# 0.0548 Instant Te Pumpkin Spice
# 0.0548 Instant Te Kakao
# 0.0547 Slikstjerner Jordbær
# 0.0547 Slikstrimler Jordbær
# 0.0547 Sliksnører Jordbær
# 0.0527 Pepperoni Pizza
# 0.0527 Pizza
# 0.0498 Leverpostej
# 0.0498 Leverpostej
# 0.0498 Leverpostej
# 0.0488 Ostehaps
# 0.0484 Spareribs
# 0.0484 Pulled Pork
# 0.0476 Skiveost Guld
# 0.0476 Skiveost Fætter Kras
# 0.0476 Skiveost Mild Havarti
# 0.0454 Jordbærmarmelade
# 0.0454 Solbærmarmelade
# 0.0454 Hindbærmarmelade
# 0.0441 Sportssodavand 18 pk.
# 0.0432 Chokoladebar Saltkaramel
# 0.0432 Chokoladebar Orangeknas
# 0.0432 Chokoladebar Knas
# 0.0432 Chokoladebar Mælkechokolade
# 0.0432 Chokoladebar Hasselnød
# 0.0420 Kakaomælk
# 0.0420 Chokolademælk Delight
# 0.0390 Kaffe Formalet
# 0.0390 Kaffe Formalet
# 0.0373 Cookies
# 0.0371 Sportsdrik
# 0.0371 Sportsdrik
# 0.0369 Cola 18 pk.
# 0.0360 Frikadeller
# 0.0359 Slikstjerner Karamel
# 0.0359 Slikstrimler Tutti Frutti
# 0.0356 Skæreost Mellemlagret 45+
# 0.0335 Skimmelost
# 0.0335 Skimmelost
# 0.0335 Skimmelost
# 0.0335 Skimmelost
# 0.0335 Skimmelost
# 0.0312 Hvidvin
# 0.0312 Rosevin
# 0.0312 Rødvin
# 0.0306 Smøreost Krydderost
# 0.0306 Smøreost Baconost
# 0.0306 Smøreost Skinkeost
# 0.0306 Smøreost Rejeost Light
# 0.0306 Smøreost Rejeost
# 0.0306 Smøreost Champignonost
# 0.0303 Forårsruller
# 0.0303 Forårsruller
# 0.0283 Halloumi Grillost
# 0.0269 Tom Kha Noodle Soup med Wonton
# 0.0254 Opvaskestativ
# 0.0241 Indbagte Rejer med Asparges og Dildsauce
# 0.0231 Energidrik
# 0.0231 Vitamindrik
# 0.0231 Energidrik
# 0.0231 Energidrik
# 0.0231 Vitamindrik
# 0.0229 Salty Liquorice Dadelbar
# 0.0229 Cocoa Mint Dadelbar
# 0.0229 Cocoa Coconut Dadelbar
# 0.0229 Salty Caramel Dadelbar
# 0.0222 Myslibar
# 0.0220 Lim
# 0.0220 Hundefoder
# 0.0220 Elefantsnot
# 0.0208 Chokoladestænger
# 0.0154 Sportssodavand Citron Lime Sukkerfri 24 pk.
# 0.0154 Ferskensodavand Sukkerfri 24 pk.
# 0.0154 Appelsinsodavand 24 pk.
# 0.0147 Mineralvand med brus, hyldeblomst og lime
# 0.0147 Mineralvand med brus og citrus
# 0.0147 Nudler med oksekødssmag
# 0.0147 Nudler med kyllingesmag
# 0.0145 Opbevaringsboks
# 0.0124 Energidrik 8 pk.
# 0.0122 Saks
# 0.0122 Tape
# 0.0122 Indlægssål
# 0.0122 Duftkugler
# 0.0122 Hæftemaskine
# 0.0107 Energidrik 24 pk.
# 0.0107 Energidrik 24 pk.
# 0.0107 Energidrik 24 pk.
# 0.0098 Stærk sennep
# 0.0098 Hot Dog Ketchup
# 0.0098 Træningstilskud
# 0.0098 Salatmayonaise
# 0.0098 Karrydressing
# 0.0098 Sød fransk sennep
# 0.0098 French hotdogdressing
# 0.0098 Pommes Frites Dressing
# 0.0098 Burgerdressing
# 0.0080 Pizza & Pitadressing
# 0.0076 Kaffebønner
# 0.0076 Kaffebønner
# 0.0053 Forklæde
# 0.0053 Legehusholdning
# 0.0051 Opbevaringsboks
# 0.0051 Viskestykke
# 0.0051 Skærebræt
# 0.0051 Drikkeflaske
# 0.0051 Kattefoder
# 0.0051 Bøjler
# 0.0051 Køleskabsopbevaring
# 0.0051 Madkasse
# 0.0051 Plastflasker
# 0.0051 Plastikbøtter
# 0.0044 Notesblok
# 0.0044 Gulvtæppe
# 0.0044 Strømper
# 0.0044 Opbevaringskasse
# 0.0044 Opbevaringskurv
# 0.0044 Citruspresser
# 0.0044 Refleksvest
# 0.0044 Drikkeflaske
# 0.0044 Indlægssål
# 0.0044 Dørslag
# 0.0044 Opbevaringskasse
# 0.0044 Tape
# 0.0044 Notesblok
# 0.0044 Refleksovertræk
# 0.0044 Køleskabsopbevaring
# 0.0044 Dørslag
# 0.0043 Opbevaringsboks
# 0.0043 Hundefoder
# 0.0043 Kuverter
# 0.0043 Hvidløgspresser
# 0.0043 Legehusholdning
# 0.0043 Køkkenredskaber
# 0.0043 Sprayflaske
# 0.0043 Kattefoder
# 0.0043 Kålsnitter
# 0.0043 Notesblok
# 0.0043 Drikkeflaske
# 0.0043 Plastikbøtter
# 0.0043 Flaske
# 0.0043 Olie/eddike flaske
# 0.0043 Duftpose
# 0.0043 Postemballage
# 0.0043 Duftkugler
# 0.0042 Kogebøger
# 0.0042 Skriveunderlag
# 0.0042 Computertaske
# 0.0042 Plastikbøtter
# 0.0042 T-shirt
# 0.0040 Sweatshirt
# 0.0040 Sweatshirt
# 0.0040 T-shirt
# 0.0040 Elkedel
# 0.0040 Laptoppude
# 0.0037 Tørklæde
# 0.0037 Californisk Rødvin
# 0.0037 Vægur
# 0.0037 Italiensk Rødvin
# 0.0037 Chilensk Rosevin
# 0.0037 Halstørklæde
# 0.0037 Californisk Hvidvin
# 0.0037 Skiundertøj
# 0.0037 Tavle
# 0.0037 Fuglefoder
# 0.0037 Minihakker
# 0.0037 Magasinholder
# 0.0037 Legehusholdning
# 0.0037 Svedbånd
# 0.0037 Kalender
# 0.0037 Knagerække
# 0.0037 Flaske
# 0.0037 Italiensk Hvidvin
# 0.0037 Chilensk Rødvin
# 0.0037 Chilensk Hvidvin
# 0.0037 Køleskabsopbevaring
# 0.0034 Plakat
# 0.0034 Opbevaringsboks
# 0.0034 Skistrømper
# 0.0034 Skiundertøj
# 0.0034 Airfryertilbehør
# 0.0012 Australsk Hvidvin
# 0.0012 Blender
# 0.0012 Mandolinjern
# 0.0012 Massageapparat
# 0.0012 Massagemåtte
# 0.0012 Spansk Hvidvin
# 0.0012 Australsk Rødvin
# 0.0012 Spansk Rødvin
# 0.0012 Vasketøjskurv
# 0.0012 Paninigrill
# 0.0012 Massagemaskine
# 0.0012 Reol
# 0.0012 Rullevogn
# 0.0012 Bordlampe

# %%
# Build reordered DataFrame of test_df with probabilities
# Uses existing variables: probas, sorted_indices, test_df
ordered_indices = sorted_indices.copy()
test_df_ordered = test_df.iloc[ordered_indices].copy()
test_df_ordered['probability'] = probas[ordered_indices, 1]

final_df = test_df_ordered[test_df_ordered['probability']>0.5]
final_df.to_csv("../data/csv/mail_groceries.csv", index=False)

# %% [markdown]
# # Send EMAIL

# %%
# Email configuration
SMTP_SERVER = "smtp.gmail.com"  # For Gmail
SMTP_PORT = 587  # TLS port

# Get credentials from environment variables
EMAIL_ADDRESS = os.getenv("EMAIL_ADDRESS")
EMAIL_PASSWORD = os.getenv("EMAIL_PASSWORD")  # Use app password for Gmail

# Verify credentials are loaded
if not EMAIL_ADDRESS or not EMAIL_PASSWORD:
    print("Warning: EMAIL_ADDRESS and EMAIL_PASSWORD must be set in your .env file")
else:
    print(f"Email configured for: {EMAIL_ADDRESS}")
# Out:
# Email configured for: marcus.pythontest@gmail.com

# %%
def send_html_email(to_email, subject, html_body):
    """Send an email with HTML content."""
    try:
        # Create message
        msg = MIMEMultipart('alternative')
        msg['Subject'] = subject
        msg['From'] = EMAIL_ADDRESS
        msg['To'] = to_email
        
        # Add HTML content
        html_part = MIMEText(html_body, 'html')
        msg.attach(html_part)
        
        # Connect and send
        with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as server:
            server.starttls()
            server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
            server.send_message(msg)
        
        print(f"✓ HTML email sent successfully to {to_email}")
        return True
    except Exception as e:
        print(f"✗ Failed to send email: {e}")
        return False

# %%
CSV_PATH = "../data/csv/mail_groceries.csv"


def build_grocery_grid_html(csv_path=CSV_PATH, period_text=None):
    """Return an HTML string with a 2-column grid for email.
    If period_text is provided, it is shown at the top of the email.
    """
    df = pd.read_csv(csv_path)
    df = df.fillna("")

    def card_html(row):
        img = row.get("public_urls", "") or row.get("image_url", "")
        name = row.get("product_name") or row.get("translated_product") or "Item"
        brand = row.get("brand", "")
        price = row.get("price", "")
        store = row.get("store_name", "")
        quantity = row.get("quantity", "")
        unit_type = row.get("unit_type", "")
        units = row.get("units", "")

        price_display = f"{float(price):.2f},-" if price != "" else ""
        qty = f"{quantity} {unit_type}".strip() if quantity != "" else ""
        unit = f"{units}x {qty}" if units not in ["", None] else qty

        optional_brand = f"<div style='font-size:12px;color:#666;margin-top:4px;'>{brand}</div>" if brand else ""
        optional_unit = f"<div style='font-size:12px;color:#666;'>{unit}</div>" if unit else ""
        img_tag = (
            f"<img src='{img}' alt='{name}' style='width:100%;height:180px;object-fit:cover;border-radius:8px 8px 0 0;'/>"
            if img
            else "<div style='height:180px;background:#eee;border-radius:8px 8px 0 0;'></div>"
        )

        return f"""
                <div style='border:1px solid #e5e5e5;border-radius:10px;overflow:hidden;font-family:Arial, sans-serif;background:#fff;'>
                  {img_tag}
                  <div style='padding:10px;'>
                    <div style='font-weight:600;font-size:14px;color:#222;'>{name}</div>
                    {optional_brand}
                    <div style='font-size:13px;color:#111;margin-top:6px;'>{price_display}</div>
                    <div style='font-size:12px;color:#666;'>{store}</div>
                  </div>
                </div>
                """

    cards = [card_html(row) for _, row in df.iterrows()]

    rows = []
    for i in range(0, len(cards), 2):
        chunk = cards[i : i + 2]
        cells = "".join(
            f"<td style='padding:8px;vertical-align:top;width:50%;'>" + card + "</td>" for card in chunk
        )
        rows.append(f"<tr>{cells}</tr>")

    table_rows = "\n".join(rows)

    # Optional sales period block at the top
    period_block = (
        f"<p style='color:#222;margin:0 0 12px 0;font-weight:600;'>" + period_text + "</p>"
        if period_text else ""
    )

    html = f"""
            <html>
              <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
                <div style='max-width:960px;margin:0 auto;'>
                  {period_block}
                  <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
                  <table role='presentation' cellpadding='0' cellspacing='0' border='0' style='border-collapse:collapse;width:100%;table-layout:fixed;'>
                    {table_rows}
                  </table>
                </div>
              </body>
            </html>
            """
    return html

# %%
# Build HTML for topitems (2-column grid) with sales period at top

# Compute period from latest_csv (YYYY-MM-DD) to +6 days
try:
    start_date = datetime.strptime(latest_csv, "%Y-%m-%d").date()
    end_date = start_date + timedelta(days=6)
    period_text = f"Sales in period {start_date.strftime('%d/%m')} - {end_date.strftime('%d/%m')}"
except Exception:
    period_text = None

try:
    html_content = build_grocery_grid_html(period_text=period_text)
    preview = html_content[:500] + ("..." if len(html_content) > 500 else "")
    print("HTML preview (first 500 chars):")
    print(preview)
except FileNotFoundError:
    html_content = ""
    print("CSV not found at ../data/csv/mail_groceries.csv")

subject_line = f"Weekly Grocery Highlights — {datetime.today().strftime('%Y-%m-%d')}"

# send_html_email(
#     to_email="thorupmettek@gmail.com ",
#     subject=subject_line,
#     html_body=html_content
# )
# send_html_email(
#     to_email="marcus.presutti.eu@gmail.com",
#     subject=subject_line,
#     html_body=html_content
# )
# Out:
# HTML preview (first 500 chars):
#
#             <html>
#               <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
#                 <div style='max-width:960px;margin:0 auto;'>
#                   <p style='color:#222;margin:0 0 12px 0;font-weight:600;'>Sales in period 02/01 - 08/01</p>
#                   <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
#                   <table role='presentation' cellpadding='0' ce...
