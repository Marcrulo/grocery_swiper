# %% [markdown]
# # Imports

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import os
import pandas as pd
import datetime
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier

import sqlite3

from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %% [markdown]
# # Calculate top items

# %% [markdown]
# ## Load data

# %%
CSV_PATH = "../data/csv/processed/"
files    = os.listdir(CSV_PATH)
csvs     = sorted([file.split('_')[1].split('.')[0] for file in files])

historic_csvs = csvs[:-1]
train_df      = pd.concat([pd.read_csv(f"{CSV_PATH}products_{csv}.csv") for csv in historic_csvs], ignore_index=True)

latest_csv = csvs[-1]
test_df    = pd.read_csv(f"{CSV_PATH}products_{latest_csv}.csv")

# %%
conn = sqlite3.connect("../data/sql/swipes.db")
labels = pd.read_sql_query("SELECT data_id, is_liked, is_superliked, is_passed FROM swipes", conn)
conn.close()

# %% [markdown]
# ## Pre-processing

# %%
stop_words = ['i','på','og','til']
vectorizer = CountVectorizer(binary=True, lowercase=True, stop_words=stop_words)
train_sentences = train_df['product_name'].tolist()
train_product_encoding = vectorizer.fit_transform(train_sentences).toarray()

test_sentences = test_df['product_name'].tolist()
test_product_encoding = vectorizer.transform(test_sentences).toarray()

# %%
onehot = ['brand','category']
preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown='ignore'), onehot),
    ("num", StandardScaler(), ['price'])
])
train_onehot = preprocessor.fit_transform(train_df).toarray()
test_onehot  = preprocessor.transform(test_df).toarray()
num_categories = sum(len(c) for c in preprocessor.named_transformers_['cat'].categories_)
print(f"Number of categories after one-hot encoding: {num_categories}")
# Out:
# Number of categories after one-hot encoding: 782

# %%
train_preprocessed = np.hstack((train_product_encoding, train_onehot))
test_preprocessed  = np.hstack((test_product_encoding, test_onehot))

train_df_preprocessed = pd.DataFrame(train_preprocessed, columns=[f"feature_{i}" for i in range(train_preprocessed.shape[1])])
train_df_preprocessed = pd.merge(train_df, train_df_preprocessed, left_index=True, right_index=True)

test_df_preprocessed = pd.DataFrame(test_preprocessed, columns=[f"feature_{i}" for i in range(test_preprocessed.shape[1])])
test_df_preprocessed = pd.merge(test_df, test_df_preprocessed, left_index=True, right_index=True)

# %%
train_df_features = train_df_preprocessed.iloc[:, len(train_df.columns):]
train_df_features['data_id'] = train_df_preprocessed['data_id']
train_df_features = pd.merge(train_df_features, labels, on='data_id', how='inner')

Xtrain = train_df_features.drop(columns=['data_id', 'is_liked', 'is_superliked', 'is_passed']).to_numpy()
ytrain = (train_df_features['is_liked'] | train_df_features['is_superliked']).to_numpy()

test_df_features  = test_df_preprocessed.iloc[:, len(test_df.columns):]
test_df_features['data_id'] = test_df_preprocessed['data_id']

Xtest = test_df_features.drop(columns=['data_id']).to_numpy()

# %% [markdown]
# ## Inference

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='cosine')

# Duplicate samples based on weights
weights = np.where(train_df_features['is_superliked'] == 1, 3, 1)

# Repeat each row according to its weight
indices = np.repeat(np.arange(len(train_df_features)), weights)

Xtrain_weighted = Xtrain[indices]
ytrain_weighted = ytrain[indices]
train_df_features_weighted = train_df_features.iloc[indices].reset_index(drop=True)

knn.fit(Xtrain_weighted, ytrain_weighted)
# Out:
# KNeighborsClassifier(metric='cosine')

# %%
# Probabilities for all test samples, and print in descending order of probability of being liked
probas = knn.predict_proba(Xtest)
sorted_indices = np.argsort(-probas[:, 1])  # Sort by probability of being liked (class 1)
for idx in sorted_indices:
    data_id = test_df_features.iloc[idx]['data_id']
    product_name = test_df[test_df['data_id'] == data_id]['product_name'].values[0]
    print(f"{probas[idx, 1]:.4f} {product_name}")
# Out:
# 1.0000 Hundeposer
# 1.0000 Økologiske æg M/L
# 1.0000 Agurk
# 1.0000 Grapefrugt
# 1.0000 Duftkugler
# 1.0000 Indlægssål
# 1.0000 Duftpose
# 1.0000 Laks i skiver
# 1.0000 Gulerødder
# 1.0000 Tomater
# 1.0000 Hakkede Tomater med urter
# 1.0000 Hakkede Tomater
# 1.0000 Drikkeyoghurt Jordbær & Banan
# 1.0000 Drikkeyoghurt Multifrugt
# 1.0000 Gulerødder
# 1.0000 Drikkeyoghurt Jordbær
# 1.0000 Lakseside
# 1.0000 Salami
# 1.0000 Lufttørret Skinke
# 1.0000 Laks i skiver
# 1.0000 Chorizo
# 1.0000 Jamon Serrano
# 1.0000 Skinke
# 1.0000 Laks
# 1.0000 Kikærter
# 1.0000 Bønner
# 1.0000 Salami Milano Salame
# 1.0000 Mortadella
# 1.0000 Spidskål
# 1.0000 Salami Spicy Ventricina
# 1.0000 Rodfrugter
# 1.0000 Appelsiner
# 1.0000 Salchichón
# 1.0000 Æggesalat 30% mindre fedt
# 1.0000 Kyllingebryst
# 1.0000 Hakket kalv og grisekød 8-12%
# 1.0000 Rejer
# 1.0000 Kylling
# 1.0000 Hamburgerryg
# 1.0000 Tomater
# 1.0000 Schwarzwaldskinke
# 1.0000 Duftkugler
# 1.0000 Hakket grisekød 8-12%
# 1.0000 Kyllingebrystfilet
# 1.0000 Kyllingeunderlår
# 1.0000 Toiletpapir
# 1.0000 Kyllingeoverlår
# 1.0000 Kylling & Baconsalat
# 1.0000 Sønderjysk Spegepølse
# 1.0000 Hakket kylling 3-7%
# 1.0000 Hakket kylling 3-7%
# 1.0000 Rejer
# 0.8000 Knagerække
# 0.8000 Hundefoder
# 0.8000 Skiundertøj
# 0.8000 Fuglefoder
# 0.8000 Surdejsboller
# 0.8000 Oksespegepølse
# 0.8000 Vandmelon
# 0.8000 Hyldeblomst drik
# 0.8000 Hundefoder
# 0.8000 Gojibær
# 0.8000 Kattesnacks
# 0.8000 Finvalsede Havregryn
# 0.8000 Æggesalat
# 0.8000 Finthakket  Skinkesalat
# 0.8000 Frugtstænger
# 0.8000 Kødpølse
# 0.8000 Kalkunspegepølse - Den lette
# 0.8000 Vannameirejer
# 0.8000 Krabbesalat
# 0.8000 Hytteost
# 0.8000 Hvedepitabrød
# 0.8000 Kødpølse - Den lette
# 0.8000 Kartoffelspegepølse
# 0.8000 Tun i vand
# 0.8000 Hundesnacks
# 0.8000 Bøjler
# 0.8000 Saks
# 0.8000 Køkkenrulle
# 0.8000 Vægur
# 0.8000 Legehusholdning
# 0.8000 Affaldsposer
# 0.8000 Jægerpølse - Den lette
# 0.8000 Tørklæde
# 0.8000 Tegnestifter
# 0.6000 Lasagneplader
# 0.6000 Fuet
# 0.6000 Smoothie
# 0.6000 Paté Hvidløg
# 0.6000 Flæsk i skiver
# 0.6000 Baconskiver
# 0.6000 Tun i olie
# 0.6000 Havrekiks med frugt
# 0.6000 Hønsesalat
# 0.6000 Postemballage
# 0.6000 Notesblok
# 0.6000 Kuverter
# 0.6000 Røget Medister
# 0.6000 Kattefoder
# 0.6000 Træningstilskud
# 0.6000 Æblejuice
# 0.6000 Kattefoder
# 0.6000 Æblejuice
# 0.6000 Pasta
# 0.6000 Naturel Skyr
# 0.6000 Vanilje Skyr
# 0.6000 Rabeber & Æble Skyr
# 0.6000 Drikkeklar saft Jordbær
# 0.4000 Jordbær Frugtdrik
# 0.4000 Tandbørste
# 0.4000 Hønsekødssuppe
# 0.4000 Kakaomælk
# 0.4000 Drikkeklar saft Original
# 0.4000 Wonder Ispinde
# 0.4000 Legehusholdning
# 0.4000 Double Sunlover Ispinde
# 0.4000 Kyllingelever
# 0.4000 Drikkeklar saft Citron
# 0.4000 Drikkeklar saft Kiwi
# 0.4000 Deo Roll-on
# 0.4000 Tandpasta
# 0.4000 Deo Roll-on
# 0.4000 Kakaomælk
# 0.4000 Chokolademælk Delight
# 0.4000 Multifrugtjuice
# 0.4000 Nudler
# 0.4000 Ispinde
# 0.4000 Bacontern
# 0.4000 Iskaffe
# 0.4000 Hakket oksekød 4-7%
# 0.4000 Deospray
# 0.4000 Tamponer
# 0.4000 Træningstilskud
# 0.4000 Trusseindlæg
# 0.4000 Bind
# 0.4000 Corn Cakes Paprika
# 0.4000 Grød
# 0.4000 Hamburgerryg
# 0.4000 Kyllingebryst
# 0.4000 Hårmousse
# 0.4000 Vaniljedrik
# 0.4000 Hårspray
# 0.4000 Hårspray
# 0.2000 Cafe Sandwich Grov
# 0.2000 Slikposer
# 0.2000 Bolsjer
# 0.2000 Slikposer
# 0.2000 Slikposer
# 0.2000 Slikposer
# 0.2000 Slikpose Eventyrland Rainbow Edition
# 0.2000 Skyllemiddel
# 0.2000 Appelsinjuice
# 0.2000 Mineralvand med brus, hyldeblomst og lime
# 0.2000 Ketchup
# 0.2000 Oksekødssuppe
# 0.2000 Rugbrødsskiver
# 0.2000 Chiafrø
# 0.2000 Kakaonibs
# 0.2000 Hampefrø
# 0.2000 Minihakker
# 0.2000 Cola
# 0.2000 Sportssodavand
# 0.2000 Hindbær Frugtdrik
# 0.2000 Sport Frugtdrik
# 0.2000 Hæftemaskine
# 0.2000 Magasinholder
# 0.2000 Solbær Frugtdrik
# 0.2000 Køleskabsopbevaring
# 0.2000 Plastikbøtter
# 0.2000 Citruspresser
# 0.2000 Sprayflaske
# 0.2000 Flaske
# 0.2000 Drikkeflaske
# 0.2000 Køleskabsopbevaring
# 0.2000 Svedbånd
# 0.2000 Elefantsnot
# 0.2000 Kosttilskud
# 0.2000 Morgenmild Juice
# 0.2000 Appelsinjuice
# 0.2000 Tavle
# 0.2000 Madkasse
# 0.2000 Drikkeflaske
# 0.2000 Plastikbøtter
# 0.2000 Pære & Banan Yoghurt
# 0.2000 Plastflasker
# 0.2000 Lim
# 0.2000 Jordbær Yoghurt
# 0.2000 Kartoffel Jordskoksuppe
# 0.2000 Hytteost
# 0.2000 Mozzarella
# 0.2000 Fiskefrikadeller
# 0.2000 Kyllingepølser
# 0.2000 Choco & Nuts Granola
# 0.2000 Grillpølser
# 0.2000 Classic Granola
# 0.2000 Hotdogpølser
# 0.2000 Olivenolie
# 0.2000 Røget Medister
# 0.2000 Frankfurter
# 0.2000 Tomatsuppe
# 0.2000 Vegansk Burgerbolle
# 0.2000 Tempurarejer
# 0.2000 Granola Honningristet
# 0.2000 Kosttilskud
# 0.2000 Mineraler
# 0.2000 Red Berries Granola
# 0.2000 Fruit & Nut Granola
# 0.2000 Mineralvand
# 0.2000 Tebreve
# 0.2000 Fiskeolie
# 0.2000 Hummus
# 0.2000 Tape
# 0.2000 Drikkeflaske
# 0.0000 Køkkenredskaber
# 0.0000 Blender
# 0.0000 Mandolinjern
# 0.0000 T-shirt
# 0.0000 Opbevaringskasse
# 0.0000 Skriveunderlag
# 0.0000 Massageapparat
# 0.0000 Massagemåtte
# 0.0000 Refleksvest
# 0.0000 Computertaske
# 0.0000 Køleskabsopbevaring
# 0.0000 Vaskemiddel-tabs
# 0.0000 Maskinopvask-tabs
# 0.0000 Rengøringssvampe
# 0.0000 Jordbærmarmelade
# 0.0000 Hindbærmarmelade
# 0.0000 Kyllingespyd
# 0.0000 Californisk Hvidvin
# 0.0000 Californisk Rødvin
# 0.0000 Revet ost Mexitopping
# 0.0000 Sour Cream & Onion Chips
# 0.0000 Flydende sæbe
# 0.0000 Paprikachips
# 0.0000 Revet ost Pizzatopping
# 0.0000 Balsamico & Tomatochips
# 0.0000 Leverpostej
# 0.0000 Gyros
# 0.0000 Makrelfilet i Tomat
# 0.0000 Makrel Små Stykker
# 0.0000 Choko Crunch
# 0.0000 Classic Crunch
# 0.0000 Pirogger Original
# 0.0000 Pirogger Chili Cheese
# 0.0000 Bagels Grov
# 0.0000 Bagels Plain
# 0.0000 Bagels chili og cheddar
# 0.0000 Solbærmarmelade
# 0.0000 Sea Salt Chips
# 0.0000 Tom Kha Noodle Soup med Wonton
# 0.0000 Smøreost Baconost
# 0.0000 Smøreost Rejeost Light
# 0.0000 Smøreost Champignonost
# 0.0000 Smøreost Skinkeost
# 0.0000 Smøreost Rejeost
# 0.0000 Smøreost Krydderost
# 0.0000 Tom Yum Suppe
# 0.0000 Frikadeller
# 0.0000 Shampoo
# 0.0000 Kiks
# 0.0000 Balsam
# 0.0000 Skæreost Mellemlagret 45+
# 0.0000 Pulled Pork
# 0.0000 Spareribs
# 0.0000 Italiensk Hvidvin
# 0.0000 Chilensk Rødvin
# 0.0000 Chilensk Hvidvin
# 0.0000 Chilensk Rosevin
# 0.0000 Italiensk Rødvin
# 0.0000 Pepperoni Pizza
# 0.0000 Nudler med kyllingesmag
# 0.0000 Nudler med oksekødssmag
# 0.0000 Pizza
# 0.0000 Sport + knækbrød
# 0.0000 Indbagte Rejer med Asparges og Dildsauce
# 0.0000 Skimmelost
# 0.0000 Ostehaps
# 0.0000 Falafel
# 0.0000 Corn Cakes Sour Cream & Onion
# 0.0000 Corn Cakes Pizza
# 0.0000 Surdejsbaguette
# 0.0000 Hvedekerneboller
# 0.0000 Surdejsboller
# 0.0000 Indbagt Laks med Spinat og Ostesauce
# 0.0000 Indbagt Laks med Julienne sauce
# 0.0000 Leverpostej
# 0.0000 Leverpostej
# 0.0000 Energidrik
# 0.0000 Energidrik
# 0.0000 Energidrik
# 0.0000 Energidrik 24 pk.
# 0.0000 Energidrik 24 pk.
# 0.0000 Energidrik 24 pk.
# 0.0000 Ravioli Chicken Lemon
# 0.0000 Smørbar
# 0.0000 Smør
# 0.0000 Kyllingekebab
# 0.0000 Delikatess knækbrød
# 0.0000 Surdeg flerkorn knækbrød
# 0.0000 Kød- og Melboller
# 0.0000 Spansk Hvidvin
# 0.0000 Australsk Rødvin
# 0.0000 Spansk Rødvin
# 0.0000 Australsk Hvidvin
# 0.0000 Maskinopvask-gel
# 0.0000 Øl - Alkoholfri
# 0.0000 Melboller
# 0.0000 Kyllingenuggets
# 0.0000 Cocoa Coconut Dadelbar
# 0.0000 Cocoa Mint Dadelbar
# 0.0000 Salty Liquorice Dadelbar
# 0.0000 Skiveost Guld
# 0.0000 Skiveost Fætter Kras
# 0.0000 Skiveost Mild Havarti
# 0.0000 Kaffe Formalet
# 0.0000 Kaffe Formalet
# 0.0000 Halloumi Grillost
# 0.0000 Pizzadej
# 0.0000 Solskinsboller
# 0.0000 Energidrik 8 pk.
# 0.0000 Forårsruller
# 0.0000 Forårsruller
# 0.0000 Rosevin
# 0.0000 Rødvin
# 0.0000 Hvidvin
# 0.0000 Cookies
# 0.0000 Havreknækbrød
# 0.0000 Solsikkekerne & Quinoa knækbrød
# 0.0000 Skimmelost
# 0.0000 Skimmelost
# 0.0000 Slikpose Eventyrland Sour
# 0.0000 Slikposer
# 0.0000 Salty Caramel Dadelbar
# 0.0000 Slikstrimler Jordbær
# 0.0000 Slikstrimler Tutti Frutti
# 0.0000 Kaffebønner
# 0.0000 Kaffebønner
# 0.0000 Chokoladestænger
# 0.0000 Skimmelost
# 0.0000 Skimmelost
# 0.0000 Myslibar
# 0.0000 Slikstjerner Jordbær
# 0.0000 Slikstjerner Karamel
# 0.0000 Sliksnører Jordbær
# 0.0000 Sild
# 0.0000 Vaskemiddel-flydende
# 0.0000 Skistrømper
# 0.0000 Vaskemiddel-flydende
# 0.0000 Vaskepulver
# 0.0000 Potato Grids
# 0.0000 Curly Fries
# 0.0000 Vaskemiddel-flydende
# 0.0000 Vitamindrik
# 0.0000 Vitamindrik
# 0.0000 Sportsdrik
# 0.0000 Rengøring - universal
# 0.0000 Sportsdrik
# 0.0000 Pommes Frites Slim
# 0.0000 Træningstilskud
# 0.0000 Chokoladebar
# 0.0000 Chokoladebar
# 0.0000 Chokoladebar
# 0.0000 Pizzasauce Basilikum
# 0.0000 Mineralvand med brus og citrus
# 0.0000 Tipo 00 Hvedemel
# 0.0000 Rugmel
# 0.0000 Dørslag
# 0.0000 Indlægssål
# 0.0000 Hot Dog Ketchup
# 0.0000 Proteinbar
# 0.0000 Chokoladebar Saltkaramel
# 0.0000 Chokoladebar Hasselnød
# 0.0000 Chokoladebar Knas
# 0.0000 Chokoladebar Orangeknas
# 0.0000 Chokoladebar Mælkechokolade
# 0.0000 Proteinbar
# 0.0000 Manitobamel
# 0.0000 Opbevaringskasse
# 0.0000 Solsikkerugbrød
# 0.0000 Kirsebær Yoghurt
# 0.0000 Flaske
# 0.0000 Skyllemiddel
# 0.0000 Appelsinsodavand 24 pk.
# 0.0000 Ferskensodavand Sukkerfri 24 pk.
# 0.0000 Strømper
# 0.0000 Vasketøjskurv
# 0.0000 Gulvtæppe
# 0.0000 Salatmayonaise
# 0.0000 Stærk sennep
# 0.0000 Pizza & Pitadressing
# 0.0000 French hotdogdressing
# 0.0000 Pommes Frites Dressing
# 0.0000 Burgerdressing
# 0.0000 Sød fransk sennep
# 0.0000 Karrydressing
# 0.0000 Sportssodavand Citron Lime Sukkerfri 24 pk.
# 0.0000 Cola 18 pk.
# 0.0000 Sportssodavand 18 pk.
# 0.0000 Tape
# 0.0000 Olie/eddike flaske
# 0.0000 Viskestykke
# 0.0000 Tekstilpleje
# 0.0000 Reol
# 0.0000 Laptoppude
# 0.0000 Kalender
# 0.0000 Skiundertøj
# 0.0000 Dørslag
# 0.0000 Kogebøger
# 0.0000 Bordlampe
# 0.0000 Refleksovertræk
# 0.0000 Kålsnitter
# 0.0000 Skærebræt
# 0.0000 Sportssodavand
# 0.0000 Overstregningstusch
# 0.0000 Opbevaringsboks
# 0.0000 Hvedemel
# 0.0000 Forklæde
# 0.0000 Plastikbøtter
# 0.0000 Rullevogn
# 0.0000 Blyant
# 0.0000 Notesblok
# 0.0000 Notesblok
# 0.0000 Massagemaskine
# 0.0000 Paninigrill
# 0.0000 Airfryertilbehør
# 0.0000 Opvaskestativ
# 0.0000 Halstørklæde
# 0.0000 T-shirt
# 0.0000 Sweatshirt
# 0.0000 Sweatshirt
# 0.0000 Opbevaringsboks
# 0.0000 Opbevaringskurv
# 0.0000 Opbevaringsboks
# 0.0000 Plakat
# 0.0000 Hvidløgspresser
# 0.0000 Elkedel
# 0.0000 Legehusholdning
# 0.0000 Finvalsede Havregryn
# 0.0000 Opbevaringsboks
# 0.0000 Instant Te Kakao
# 0.0000 Instant Te Vanilje
# 0.0000 Instant Te Grøn Te
# 0.0000 Instant Te Pumpkin Spice
# 0.0000 Instant Te Choco Orange
# 0.0000 Instant Te Karamel
# 0.0000 Maskinopvask-tabs

# %%
# Build reordered DataFrame of test_df with probabilities
# Uses existing variables: probas, sorted_indices, test_df
ordered_indices = sorted_indices.copy()
test_df_ordered = test_df.iloc[ordered_indices].copy()
test_df_ordered['probability'] = probas[ordered_indices, 1]

final_df = test_df_ordered[test_df_ordered['probability']>0.5]
final_df.to_csv("../data/csv/mail_groceries.csv", index=False)

# %% [markdown]
# # Send EMAIL

# %%
# Email configuration
SMTP_SERVER = "smtp.gmail.com"  # For Gmail
SMTP_PORT = 587  # TLS port

# Get credentials from environment variables
EMAIL_ADDRESS = os.getenv("EMAIL_ADDRESS")
EMAIL_PASSWORD = os.getenv("EMAIL_PASSWORD")  # Use app password for Gmail

# Verify credentials are loaded
if not EMAIL_ADDRESS or not EMAIL_PASSWORD:
    print("Warning: EMAIL_ADDRESS and EMAIL_PASSWORD must be set in your .env file")
else:
    print(f"Email configured for: {EMAIL_ADDRESS}")
# Out:
# Warning: EMAIL_ADDRESS and EMAIL_PASSWORD must be set in your .env file

# %%
def send_html_email(to_email, subject, html_body):
    """Send an email with HTML content."""
    try:
        # Create message
        msg = MIMEMultipart('alternative')
        msg['Subject'] = subject
        msg['From'] = EMAIL_ADDRESS
        msg['To'] = to_email
        
        # Add HTML content
        html_part = MIMEText(html_body, 'html')
        msg.attach(html_part)
        
        # Connect and send
        with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as server:
            server.starttls()
            server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
            server.send_message(msg)
        
        print(f"✓ HTML email sent successfully to {to_email}")
        return True
    except Exception as e:
        print(f"✗ Failed to send email: {e}")
        return False

# %%
CSV_PATH = "../data/csv/mail_groceries.csv"


def build_grocery_grid_html(csv_path=CSV_PATH, period_text=None):
    """Return an HTML string with a 2-column grid for email.
    If period_text is provided, it is shown at the top of the email.
    """
    df = pd.read_csv(csv_path)
    df = df.fillna("")

    def card_html(row):
        img = row.get("public_urls", "") or row.get("image_url", "")
        name = row.get("product_name") or row.get("translated_product") or "Item"
        brand = row.get("brand", "")
        price = row.get("price", "")
        store = row.get("store_name", "")
        quantity = row.get("quantity", "")
        unit_type = row.get("unit_type", "")
        units = row.get("units", "")

        price_display = f"{float(price):.2f},-" if price != "" else ""
        qty = f"{quantity} {unit_type}".strip() if quantity != "" else ""
        unit = f"{units}x {qty}" if units not in ["", None] else qty

        optional_brand = f"<div style='font-size:12px;color:#666;margin-top:4px;'>{brand}</div>" if brand else ""
        optional_unit = f"<div style='font-size:12px;color:#666;'>{unit}</div>" if unit else ""
        img_tag = (
            f"<img src='{img}' alt='{name}' style='width:100%;height:180px;object-fit:cover;border-radius:8px 8px 0 0;'/>"
            if img
            else "<div style='height:180px;background:#eee;border-radius:8px 8px 0 0;'></div>"
        )

        return f"""
                <div style='border:1px solid #e5e5e5;border-radius:10px;overflow:hidden;font-family:Arial, sans-serif;background:#fff;'>
                  {img_tag}
                  <div style='padding:10px;'>
                    <div style='font-weight:600;font-size:14px;color:#222;'>{name}</div>
                    {optional_brand}
                    <div style='font-size:13px;color:#111;margin-top:6px;'>{price_display}</div>
                    <div style='font-size:12px;color:#666;'>{store}</div>
                  </div>
                </div>
                """

    cards = [card_html(row) for _, row in df.iterrows()]

    rows = []
    for i in range(0, len(cards), 2):
        chunk = cards[i : i + 2]
        cells = "".join(
            f"<td style='padding:8px;vertical-align:top;width:50%;'>" + card + "</td>" for card in chunk
        )
        rows.append(f"<tr>{cells}</tr>")

    table_rows = "\n".join(rows)

    # Optional sales period block at the top
    period_block = (
        f"<p style='color:#222;margin:0 0 12px 0;font-weight:600;'>" + period_text + "</p>"
        if period_text else ""
    )

    html = f"""
            <html>
              <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
                <div style='max-width:960px;margin:0 auto;'>
                  {period_block}
                  <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
                  <table role='presentation' cellpadding='0' cellspacing='0' border='0' style='border-collapse:collapse;width:100%;table-layout:fixed;'>
                    {table_rows}
                  </table>
                </div>
              </body>
            </html>
            """
    return html

# %%
# Build HTML for topitems (2-column grid) with sales period at top

# Compute period from latest_csv (YYYY-MM-DD) to +6 days
try:
    start_date = datetime.strptime(latest_csv, "%Y-%m-%d").date()
    end_date = start_date + timedelta(days=6)
    period_text = f"Sales in period {start_date.strftime('%d/%m')} - {end_date.strftime('%d/%m')}"
except Exception:
    period_text = None

try:
    html_content = build_grocery_grid_html(period_text=period_text)
    preview = html_content[:500] + ("..." if len(html_content) > 500 else "")
    print("HTML preview (first 500 chars):")
    print(preview)
except FileNotFoundError:
    html_content = ""
    print("CSV not found at ../data/csv/mail_groceries.csv")

subject_line = f"Weekly Grocery Highlights — {datetime.today().strftime('%Y-%m-%d')}"

# send_html_email(
#     to_email="thorupmettek@gmail.com ",
#     subject=subject_line,
#     html_body=html_content
# )
# send_html_email(
#     to_email="marcus.presutti.eu@gmail.com",
#     subject=subject_line,
#     html_body=html_content
# )
# Out:
# HTML preview (first 500 chars):
#
#             <html>
#               <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
#                 <div style='max-width:960px;margin:0 auto;'>
#                   <p style='color:#222;margin:0 0 12px 0;font-weight:600;'>Sales in period 02/01 - 08/01</p>
#                   <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
#                   <table role='presentation' cellpadding='0' ce...
