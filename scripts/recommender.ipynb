# %% [markdown]
# # Imports

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import os
import pandas as pd
import datetime
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

import sqlite3

from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %% [markdown]
# # Calculate top items

# %% [markdown]
# ## Load data

# %%
CSV_PATH = "../data/csv/processed/"
files    = os.listdir(CSV_PATH)
csvs     = sorted([file.split('_')[1].split('.')[0] for file in files])

historic_csvs = csvs[:-1]
train_df      = pd.concat([pd.read_csv(f"{CSV_PATH}products_{csv}.csv") for csv in historic_csvs], ignore_index=True)

latest_csv = csvs[-1]
test_df    = pd.read_csv(f"{CSV_PATH}products_{latest_csv}.csv")

# %%
conn = sqlite3.connect("../data/sql/swipes.db")
labels = pd.read_sql_query("SELECT data_id, is_liked, is_superliked, is_passed FROM swipes", conn)
conn.close()

# %% [markdown]
# ## Pre-processing

# %%
stop_words = ['i','på','og','til']
vectorizer = CountVectorizer(binary=True, lowercase=True, stop_words=stop_words)
train_sentences = train_df['product_name'].tolist()
train_product_encoding = vectorizer.fit_transform(train_sentences).toarray()

test_sentences = test_df['product_name'].tolist()
test_product_encoding = vectorizer.transform(test_sentences).toarray()

# %%
onehot = ['brand','category']
preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown='ignore'), onehot),
    ("num", StandardScaler(), ['price'])
])
train_onehot = preprocessor.fit_transform(train_df).toarray()
test_onehot  = preprocessor.transform(test_df).toarray()
num_categories = sum(len(c) for c in preprocessor.named_transformers_['cat'].categories_)
print(f"Number of categories after one-hot encoding: {num_categories}")
# Out:
# Number of categories after one-hot encoding: 782

# %%
train_preprocessed = np.hstack((train_product_encoding, train_onehot))
test_preprocessed  = np.hstack((test_product_encoding, test_onehot))

train_df_preprocessed = pd.DataFrame(train_preprocessed, columns=[f"feature_{i}" for i in range(train_preprocessed.shape[1])])
train_df_preprocessed = pd.merge(train_df, train_df_preprocessed, left_index=True, right_index=True)

test_df_preprocessed = pd.DataFrame(test_preprocessed, columns=[f"feature_{i}" for i in range(test_preprocessed.shape[1])])
test_df_preprocessed = pd.merge(test_df, test_df_preprocessed, left_index=True, right_index=True)

# %%
train_df_features = train_df_preprocessed.iloc[:, len(train_df.columns):]
train_df_features['data_id'] = train_df_preprocessed['data_id']
train_df_features = pd.merge(train_df_features, labels, on='data_id', how='inner')

Xtrain = train_df_features.drop(columns=['data_id', 'is_liked', 'is_superliked', 'is_passed']).to_numpy()
ytrain = (train_df_features['is_liked'] | train_df_features['is_superliked']).to_numpy()

test_df_features  = test_df_preprocessed.iloc[:, len(test_df.columns):]
test_df_features['data_id'] = test_df_preprocessed['data_id']

Xtest = test_df_features.drop(columns=['data_id']).to_numpy()

# %% [markdown]
# ## Inference

# %%
# Duplicate samples based on weights
weights = np.where(train_df_features['is_superliked'] == 1, 5, 1)

# Repeat each row according to its weight
indices = np.repeat(np.arange(len(train_df_features)), weights)

Xtrain_weighted = Xtrain[indices]
ytrain_weighted = ytrain[indices]
train_df_features_weighted = train_df_features.iloc[indices].reset_index(drop=True)

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='cosine')
knn.fit(Xtrain_weighted, ytrain_weighted)
probas = knn.predict_proba(Xtest)

nb = GaussianNB()
nb.fit(Xtrain_weighted, ytrain_weighted)
probas = nb.predict_proba(Xtest)

xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(Xtrain_weighted, ytrain_weighted)
probas = xgb.predict_proba(Xtest)

# Probabilities for all test samples, and print in descending order of probability of being liked
sorted_indices = np.argsort(-probas[:, 1])  # Sort by probability of being liked (class 1)
for idx in sorted_indices:
    data_id = test_df_features.iloc[idx]['data_id']
    product_name = test_df[test_df['data_id'] == data_id]['product_name'].values[0]
    print(f"{probas[idx, 1]:.4f} {product_name}")
# Out:
# /home/mp/Desktop/grocery_swiper/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [12:33:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.9985 Lakseside
# 0.9950 Agurk
# 0.9937 Hakket kylling 3-7%
# 0.9937 Hakket kylling 3-7%
# 0.9845 Spidskål
# 0.9838 Laks i skiver
# 0.9826 Gulerødder
# 0.9826 Gulerødder
# 0.9825 Kylling
# 0.9784 Flæsk i skiver
# 0.9744 Tomater
# 0.9744 Hakkede Tomater
# 0.9744 Bønner
# 0.9744 Kikærter
# 0.9730 Chorizo
# 0.9730 Skinke
# 0.9730 Mortadella
# 0.9730 Salchichón
# 0.9730 Lufttørret Skinke
# 0.9730 Schwarzwaldskinke
# 0.9730 Jamon Serrano
# 0.9730 Salami Spicy Ventricina
# 0.9730 Salami Milano Salame
# 0.9704 Rodfrugter
# 0.9638 Tomater
# 0.9608 Hakket kalv og grisekød 8-12%
# 0.9403 Hakket grisekød 8-12%
# 0.9288 Drikkeyoghurt Jordbær & Banan
# 0.9288 Drikkeyoghurt Jordbær
# 0.9178 Hakkede Tomater med urter
# 0.8978 Kyllingeunderlår
# 0.8914 Grapefrugt
# 0.8755 Kyllingeoverlår
# 0.8755 Kyllingebrystfilet
# 0.8683 Tun i olie
# 0.8683 Tun i vand
# 0.8667 Kyllingebryst
# 0.8371 Økologiske æg M/L
# 0.8184 Fuet
# 0.8138 Appelsiner
# 0.8129 Toiletpapir
# 0.7970 Kylling & Baconsalat
# 0.7826 Laks
# 0.7826 Laks i skiver
# 0.7658 Drikkeyoghurt Multifrugt
# 0.7607 Vannameirejer
# 0.7467 Rejer
# 0.7467 Rejer
# 0.7284 Paté Hvidløg
# 0.7064 Salami
# 0.6836 Køkkenrulle
# 0.6638 Finthakket  Skinkesalat
# 0.5896 Affaldsposer
# 0.5704 Æblejuice
# 0.5691 Hummus
# 0.5677 Lasagneplader
# 0.5665 Krabbesalat
# 0.5665 Hønsesalat
# 0.5665 Æggesalat
# 0.5665 Æggesalat 30% mindre fedt
# 0.5621 Æblejuice
# 0.5523 Hakket oksekød 4-7%
# 0.5476 Vanilje Skyr
# 0.5476 Rabeber & Æble Skyr
# 0.5476 Naturel Skyr
# 0.5316 Sønderjysk Spegepølse
# 0.5149 Double Sunlover Ispinde
# 0.5088 Morgenmild Juice
# 0.5088 Appelsinjuice
# 0.5004 Appelsinjuice
# 0.5004 Multifrugtjuice
# 0.4667 Kødpølse - Den lette
# 0.4667 Kødpølse
# 0.4667 Jægerpølse - Den lette
# 0.4667 Kalkunspegepølse - Den lette
# 0.4667 Røget Medister
# 0.4667 Oksespegepølse
# 0.4667 Kartoffelspegepølse
# 0.4473 Havrekiks med frugt
# 0.4353 Hamburgerryg
# 0.3731 Jordbær Frugtdrik
# 0.2533 Røget Medister
# 0.2172 Kyllingebryst
# 0.2145 Sport Frugtdrik
# 0.2145 Solbær Frugtdrik
# 0.2145 Hindbær Frugtdrik
# 0.2145 Hyldeblomst drik
# 0.2124 Vaskemiddel-flydende
# 0.2124 Træningstilskud
# 0.1955 Jordbær Yoghurt
# 0.1827 Vandmelon
# 0.1788 Makrel Små Stykker
# 0.1768 Hamburgerryg
# 0.1454 Hvedepitabrød
# 0.1371 Hundeposer
# 0.1362 Fiskefrikadeller
# 0.1332 Chiafrø
# 0.1332 Hampefrø
# 0.1332 Kakaonibs
# 0.1317 Kartoffel Jordskoksuppe
# 0.1317 Tomatsuppe
# 0.1308 Cafe Sandwich Grov
# 0.1308 Solskinsboller
# 0.1308 Solsikkerugbrød
# 0.1308 Rugbrødsskiver
# 0.1199 Makrelfilet i Tomat
# 0.1157 Drikkeklar saft Jordbær
# 0.1133 Ispinde
# 0.1133 Wonder Ispinde
# 0.1122 Slikposer
# 0.1122 Slikposer
# 0.1122 Slikposer
# 0.1122 Slikposer
# 0.1122 Slikposer
# 0.1104 Fiskeolie
# 0.1104 Mineraler
# 0.1104 Kosttilskud
# 0.1104 Kosttilskud
# 0.1104 Maskinopvask-tabs
# 0.1040 Tegnestifter
# 0.1036 Vaniljedrik
# 0.1036 Kakaomælk
# 0.1036 Kyllingelever
# 0.1036 Corn Cakes Sour Cream & Onion
# 0.1036 Corn Cakes Paprika
# 0.1036 Mozzarella
# 0.1036 Grød
# 0.1036 Smoothie
# 0.1036 Hytteost
# 0.1036 Iskaffe
# 0.1036 Revet ost Mexitopping
# 0.1036 Revet ost Pizzatopping
# 0.1029 Kattesnacks
# 0.1029 Hundesnacks
# 0.1003 Pære & Banan Yoghurt
# 0.1003 Kirsebær Yoghurt
# 0.0967 Pizzasauce Basilikum
# 0.0956 Træningstilskud
# 0.0956 Kyllingespyd
# 0.0948 Baconskiver
# 0.0948 Bacontern
# 0.0947 Red Berries Granola
# 0.0947 Choco & Nuts Granola
# 0.0947 Classic Granola
# 0.0947 Fruit & Nut Granola
# 0.0928 Hvedekerneboller
# 0.0928 Surdejsboller
# 0.0928 Surdejsbaguette
# 0.0919 Surdejsboller
# 0.0887 Hotdogpølser
# 0.0887 Frankfurter
# 0.0887 Grillpølser
# 0.0887 Kyllingekebab
# 0.0887 Vaskemiddel-tabs
# 0.0887 Kyllingepølser
# 0.0887 Vegansk Burgerbolle
# 0.0847 Indbagt Laks med Spinat og Ostesauce
# 0.0847 Indbagt Laks med Julienne sauce
# 0.0805 Mineralvand
# 0.0805 Rengøringssvampe
# 0.0805 Finvalsede Havregryn
# 0.0805 Tekstilpleje
# 0.0805 Nudler
# 0.0788 Olivenolie
# 0.0787 Melboller
# 0.0787 Kød- og Melboller
# 0.0787 Tandpasta
# 0.0787 Tandbørste
# 0.0755 Sportssodavand
# 0.0755 Sportssodavand
# 0.0755 Cola
# 0.0727 Corn Cakes Pizza
# 0.0726 Proteinbar
# 0.0723 Bagels Plain
# 0.0723 Bagels chili og cheddar
# 0.0723 Bagels Grov
# 0.0717 Maskinopvask-gel
# 0.0717 Tempurarejer
# 0.0717 Maskinopvask-tabs
# 0.0717 Solsikkekerne & Quinoa knækbrød
# 0.0717 Havreknækbrød
# 0.0717 Sild
# 0.0717 Classic Crunch
# 0.0717 Choko Crunch
# 0.0715 Slikpose Eventyrland Rainbow Edition
# 0.0715 Bolsjer
# 0.0715 Slikpose Eventyrland Sour
# 0.0708 Deospray
# 0.0708 Deo Roll-on
# 0.0708 Deo Roll-on
# 0.0686 Pasta
# 0.0639 Frugtstænger
# 0.0639 Hytteost
# 0.0639 Finvalsede Havregryn
# 0.0634 Slikstjerner Jordbær
# 0.0634 Slikstrimler Jordbær
# 0.0634 Sliksnører Jordbær
# 0.0630 Vaskemiddel-flydende
# 0.0630 Blyant
# 0.0630 Overstregningstusch
# 0.0630 Bind
# 0.0630 Tamponer
# 0.0630 Trusseindlæg
# 0.0608 Skyllemiddel
# 0.0607 Kakaomælk
# 0.0607 Chokolademælk Delight
# 0.0606 Chokoladebar
# 0.0606 Chokoladebar
# 0.0606 Chokoladebar
# 0.0600 Pirogger Chili Cheese
# 0.0600 Pirogger Original
# 0.0600 Vaskepulver
# 0.0600 Ketchup
# 0.0600 Rengøring - universal
# 0.0600 Skyllemiddel
# 0.0600 Hårmousse
# 0.0600 Instant Te Karamel
# 0.0600 Gojibær
# 0.0600 Instant Te Pumpkin Spice
# 0.0600 Instant Te Vanilje
# 0.0600 Instant Te Kakao
# 0.0600 Instant Te Grøn Te
# 0.0600 Instant Te Choco Orange
# 0.0600 Vaskemiddel-flydende
# 0.0600 Tebreve
# 0.0600 Pizzadej
# 0.0600 Leverpostej
# 0.0600 Solbærmarmelade
# 0.0600 Smørbar
# 0.0600 Smør
# 0.0600 Ravioli Chicken Lemon
# 0.0600 Leverpostej
# 0.0600 Granola Honningristet
# 0.0600 Øl - Alkoholfri
# 0.0600 Tom Yum Suppe
# 0.0600 Leverpostej
# 0.0600 Kiks
# 0.0600 Hårspray
# 0.0600 Flydende sæbe
# 0.0600 Hårspray
# 0.0600 Hindbærmarmelade
# 0.0600 Jordbærmarmelade
# 0.0594 Balsam
# 0.0594 Shampoo
# 0.0569 Ostehaps
# 0.0567 Proteinbar
# 0.0566 Delikatess knækbrød
# 0.0566 Surdeg flerkorn knækbrød
# 0.0566 Sport + knækbrød
# 0.0566 Drikkeklar saft Original
# 0.0566 Drikkeklar saft Kiwi
# 0.0566 Drikkeklar saft Citron
# 0.0566 Hvedemel
# 0.0537 Spareribs
# 0.0537 Pulled Pork
# 0.0527 Sour Cream & Onion Chips
# 0.0527 Balsamico & Tomatochips
# 0.0527 Sea Salt Chips
# 0.0527 Paprikachips
# 0.0521 Curly Fries
# 0.0521 Potato Grids
# 0.0521 Oksekødssuppe
# 0.0521 Tipo 00 Hvedemel
# 0.0521 Manitobamel
# 0.0521 Hønsekødssuppe
# 0.0521 Rugmel
# 0.0521 Pommes Frites Slim
# 0.0519 Halloumi Grillost
# 0.0510 Pizza
# 0.0510 Pepperoni Pizza
# 0.0510 Gyros
# 0.0510 Falafel
# 0.0510 Kyllingenuggets
# 0.0500 Skiveost Fætter Kras
# 0.0500 Skiveost Guld
# 0.0500 Skiveost Mild Havarti
# 0.0494 Cookies
# 0.0453 Cola 18 pk.
# 0.0453 Sportssodavand 18 pk.
# 0.0449 Skimmelost
# 0.0449 Skimmelost
# 0.0449 Skimmelost
# 0.0449 Skimmelost
# 0.0449 Skimmelost
# 0.0437 Sportsdrik
# 0.0437 Sportsdrik
# 0.0413 Slikstrimler Tutti Frutti
# 0.0413 Slikstjerner Karamel
# 0.0403 Frikadeller
# 0.0398 Rosevin
# 0.0398 Hvidvin
# 0.0398 Rødvin
# 0.0380 Elefantsnot
# 0.0380 Hundefoder
# 0.0380 Lim
# 0.0367 Kaffe Formalet
# 0.0367 Kaffe Formalet
# 0.0354 Chokoladebar Hasselnød
# 0.0354 Chokoladebar Saltkaramel
# 0.0354 Chokoladebar Knas
# 0.0354 Chokoladebar Mælkechokolade
# 0.0354 Chokoladebar Orangeknas
# 0.0340 Forårsruller
# 0.0340 Forårsruller
# 0.0327 Smøreost Rejeost Light
# 0.0327 Smøreost Skinkeost
# 0.0327 Smøreost Rejeost
# 0.0327 Smøreost Krydderost
# 0.0327 Smøreost Champignonost
# 0.0327 Smøreost Baconost
# 0.0325 Myslibar
# 0.0323 Skæreost Mellemlagret 45+
# 0.0260 Indbagte Rejer med Asparges og Dildsauce
# 0.0232 Energidrik
# 0.0232 Vitamindrik
# 0.0232 Energidrik
# 0.0232 Energidrik
# 0.0232 Vitamindrik
# 0.0231 Opvaskestativ
# 0.0222 Cocoa Mint Dadelbar
# 0.0222 Salty Liquorice Dadelbar
# 0.0222 Salty Caramel Dadelbar
# 0.0222 Cocoa Coconut Dadelbar
# 0.0211 Duftkugler
# 0.0211 Tape
# 0.0211 Indlægssål
# 0.0211 Hæftemaskine
# 0.0211 Saks
# 0.0198 Chokoladestænger
# 0.0189 Tom Kha Noodle Soup med Wonton
# 0.0177 Nudler med oksekødssmag
# 0.0177 Nudler med kyllingesmag
# 0.0177 Mineralvand med brus, hyldeblomst og lime
# 0.0177 Mineralvand med brus og citrus
# 0.0177 Ferskensodavand Sukkerfri 24 pk.
# 0.0177 Appelsinsodavand 24 pk.
# 0.0177 Sportssodavand Citron Lime Sukkerfri 24 pk.
# 0.0159 Opbevaringsboks
# 0.0140 Energidrik 8 pk.
# 0.0112 Salatmayonaise
# 0.0095 Energidrik 24 pk.
# 0.0095 Energidrik 24 pk.
# 0.0095 Energidrik 24 pk.
# 0.0089 Karrydressing
# 0.0089 Hot Dog Ketchup
# 0.0089 Sød fransk sennep
# 0.0089 Træningstilskud
# 0.0089 French hotdogdressing
# 0.0089 Pommes Frites Dressing
# 0.0089 Burgerdressing
# 0.0089 Stærk sennep
# 0.0074 Forklæde
# 0.0074 Legehusholdning
# 0.0073 Kaffebønner
# 0.0073 Kaffebønner
# 0.0069 Notesblok
# 0.0069 Plastikbøtter
# 0.0069 Flaske
# 0.0069 Kålsnitter
# 0.0069 Sprayflaske
# 0.0069 Hundefoder
# 0.0069 Hvidløgspresser
# 0.0069 Kuverter
# 0.0069 Opbevaringsboks
# 0.0069 Drikkeflaske
# 0.0069 Duftpose
# 0.0069 Postemballage
# 0.0069 Duftkugler
# 0.0069 Legehusholdning
# 0.0069 Køkkenredskaber
# 0.0069 Kattefoder
# 0.0069 Olie/eddike flaske
# 0.0066 Viskestykke
# 0.0066 Kattefoder
# 0.0066 Bøjler
# 0.0066 Plastikbøtter
# 0.0066 Køleskabsopbevaring
# 0.0066 Opbevaringsboks
# 0.0066 Skærebræt
# 0.0066 Drikkeflaske
# 0.0066 Madkasse
# 0.0066 Plastflasker
# 0.0060 Pizza & Pitadressing
# 0.0053 Kogebøger
# 0.0053 T-shirt
# 0.0053 Plastikbøtter
# 0.0053 Computertaske
# 0.0053 Skriveunderlag
# 0.0053 Knagerække
# 0.0053 Skiundertøj
# 0.0053 Køleskabsopbevaring
# 0.0053 Californisk Hvidvin
# 0.0053 Vægur
# 0.0053 Tørklæde
# 0.0053 Legehusholdning
# 0.0053 Californisk Rødvin
# 0.0053 Fuglefoder
# 0.0043 Sweatshirt
# 0.0043 Laptoppude
# 0.0043 Elkedel
# 0.0043 Sweatshirt
# 0.0043 T-shirt
# 0.0043 Plakat
# 0.0043 Skistrømper
# 0.0043 Airfryertilbehør
# 0.0043 Skiundertøj
# 0.0043 Opbevaringsboks
# 0.0037 Italiensk Rødvin
# 0.0037 Chilensk Rødvin
# 0.0037 Chilensk Hvidvin
# 0.0037 Italiensk Hvidvin
# 0.0037 Chilensk Rosevin
# 0.0037 Halstørklæde
# 0.0037 Svedbånd
# 0.0037 Magasinholder
# 0.0037 Minihakker
# 0.0037 Kalender
# 0.0037 Tavle
# 0.0037 Flaske
# 0.0034 Drikkeflaske
# 0.0034 Refleksvest
# 0.0034 Opbevaringskasse
# 0.0034 Notesblok
# 0.0034 Gulvtæppe
# 0.0034 Citruspresser
# 0.0034 Opbevaringskurv
# 0.0034 Notesblok
# 0.0034 Køleskabsopbevaring
# 0.0034 Refleksovertræk
# 0.0034 Dørslag
# 0.0034 Tape
# 0.0034 Dørslag
# 0.0034 Indlægssål
# 0.0034 Opbevaringskasse
# 0.0034 Strømper
# 0.0012 Australsk Rødvin
# 0.0012 Spansk Hvidvin
# 0.0012 Australsk Hvidvin
# 0.0012 Blender
# 0.0012 Mandolinjern
# 0.0012 Massagemåtte
# 0.0012 Massageapparat
# 0.0012 Spansk Rødvin
# 0.0012 Reol
# 0.0012 Vasketøjskurv
# 0.0012 Massagemaskine
# 0.0012 Paninigrill
# 0.0012 Bordlampe
# 0.0012 Rullevogn

# %%
# Build reordered DataFrame of test_df with probabilities
# Uses existing variables: probas, sorted_indices, test_df
ordered_indices = sorted_indices.copy()
test_df_ordered = test_df.iloc[ordered_indices].copy()
test_df_ordered['probability'] = probas[ordered_indices, 1]

final_df = test_df_ordered[test_df_ordered['probability']>0.5]
final_df.to_csv("../data/csv/mail_groceries.csv", index=False)

# %% [markdown]
# # Send EMAIL

# %%
# Email configuration
SMTP_SERVER = "smtp.gmail.com"  # For Gmail
SMTP_PORT = 587  # TLS port

# Get credentials from environment variables
EMAIL_ADDRESS = os.getenv("EMAIL_ADDRESS")
EMAIL_PASSWORD = os.getenv("EMAIL_PASSWORD")  # Use app password for Gmail

# Verify credentials are loaded
if not EMAIL_ADDRESS or not EMAIL_PASSWORD:
    print("Warning: EMAIL_ADDRESS and EMAIL_PASSWORD must be set in your .env file")
else:
    print(f"Email configured for: {EMAIL_ADDRESS}")
# Out:
# Warning: EMAIL_ADDRESS and EMAIL_PASSWORD must be set in your .env file

# %%
def send_html_email(to_email, subject, html_body):
    """Send an email with HTML content."""
    try:
        # Create message
        msg = MIMEMultipart('alternative')
        msg['Subject'] = subject
        msg['From'] = EMAIL_ADDRESS
        msg['To'] = to_email
        
        # Add HTML content
        html_part = MIMEText(html_body, 'html')
        msg.attach(html_part)
        
        # Connect and send
        with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as server:
            server.starttls()
            server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)
            server.send_message(msg)
        
        print(f"✓ HTML email sent successfully to {to_email}")
        return True
    except Exception as e:
        print(f"✗ Failed to send email: {e}")
        return False

# %%
CSV_PATH = "../data/csv/mail_groceries.csv"


def build_grocery_grid_html(csv_path=CSV_PATH, period_text=None):
    """Return an HTML string with a 2-column grid for email.
    If period_text is provided, it is shown at the top of the email.
    """
    df = pd.read_csv(csv_path)
    df = df.fillna("")

    def card_html(row):
        img = row.get("public_urls", "") or row.get("image_url", "")
        name = row.get("product_name") or row.get("translated_product") or "Item"
        brand = row.get("brand", "")
        price = row.get("price", "")
        store = row.get("store_name", "")
        quantity = row.get("quantity", "")
        unit_type = row.get("unit_type", "")
        units = row.get("units", "")

        price_display = f"{float(price):.2f},-" if price != "" else ""
        qty = f"{quantity} {unit_type}".strip() if quantity != "" else ""
        unit = f"{units}x {qty}" if units not in ["", None] else qty

        optional_brand = f"<div style='font-size:12px;color:#666;margin-top:4px;'>{brand}</div>" if brand else ""
        optional_unit = f"<div style='font-size:12px;color:#666;'>{unit}</div>" if unit else ""
        img_tag = (
            f"<img src='{img}' alt='{name}' style='width:100%;height:180px;object-fit:cover;border-radius:8px 8px 0 0;'/>"
            if img
            else "<div style='height:180px;background:#eee;border-radius:8px 8px 0 0;'></div>"
        )

        return f"""
                <div style='border:1px solid #e5e5e5;border-radius:10px;overflow:hidden;font-family:Arial, sans-serif;background:#fff;'>
                  {img_tag}
                  <div style='padding:10px;'>
                    <div style='font-weight:600;font-size:14px;color:#222;'>{name}</div>
                    {optional_brand}
                    <div style='font-size:13px;color:#111;margin-top:6px;'>{price_display}</div>
                    <div style='font-size:12px;color:#666;'>{store}</div>
                  </div>
                </div>
                """

    cards = [card_html(row) for _, row in df.iterrows()]

    rows = []
    for i in range(0, len(cards), 2):
        chunk = cards[i : i + 2]
        cells = "".join(
            f"<td style='padding:8px;vertical-align:top;width:50%;'>" + card + "</td>" for card in chunk
        )
        rows.append(f"<tr>{cells}</tr>")

    table_rows = "\n".join(rows)

    # Optional sales period block at the top
    period_block = (
        f"<p style='color:#222;margin:0 0 12px 0;font-weight:600;'>" + period_text + "</p>"
        if period_text else ""
    )

    html = f"""
            <html>
              <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
                <div style='max-width:960px;margin:0 auto;'>
                  {period_block}
                  <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
                  <table role='presentation' cellpadding='0' cellspacing='0' border='0' style='border-collapse:collapse;width:100%;table-layout:fixed;'>
                    {table_rows}
                  </table>
                </div>
              </body>
            </html>
            """
    return html

# %%
# Build HTML for topitems (2-column grid) with sales period at top

# Compute period from latest_csv (YYYY-MM-DD) to +6 days
try:
    start_date = datetime.strptime(latest_csv, "%Y-%m-%d").date()
    end_date = start_date + timedelta(days=6)
    period_text = f"Sales in period {start_date.strftime('%d/%m')} - {end_date.strftime('%d/%m')}"
except Exception:
    period_text = None

try:
    html_content = build_grocery_grid_html(period_text=period_text)
    preview = html_content[:500] + ("..." if len(html_content) > 500 else "")
    print("HTML preview (first 500 chars):")
    print(preview)
except FileNotFoundError:
    html_content = ""
    print("CSV not found at ../data/csv/mail_groceries.csv")

subject_line = f"Weekly Grocery Highlights — {datetime.today().strftime('%Y-%m-%d')}"

# send_html_email(
#     to_email="thorupmettek@gmail.com ",
#     subject=subject_line,
#     html_body=html_content
# )
# send_html_email(
#     to_email="marcus.presutti.eu@gmail.com",
#     subject=subject_line,
#     html_body=html_content
# )
# Out:
# HTML preview (first 500 chars):
#
#             <html>
#               <body style='margin:0;padding:16px;background:#f7f7f7;font-family:Arial,sans-serif;'>
#                 <div style='max-width:960px;margin:0 auto;'>
#                   <p style='color:#222;margin:0 0 12px 0;font-weight:600;'>Sales in period 02/01 - 08/01</p>
#                   <p style='color:#444;margin-top:0;margin-bottom:16px;'>Curated picks from this week's sales flyer based on your preferences.</p>
#                   <table role='presentation' cellpadding='0' ce...
